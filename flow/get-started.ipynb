# %% [markdown]
# ## MLFLow Tracking Server

# %%
import mlflow

# %%
mlflow.set_tracking_uri("http://127.0.0.1:5000")

# %%
mlflow.set_experiment("Check localhost connection")

with mlflow.start_run():
    mlflow.log_metric("test",1)
    mlflow.log_metric("Krish",2)
# Out:
# 🏃 View run peaceful-bat-963 at: http://127.0.0.1:5000/#/experiments/486478833896431808/runs/f6d2e407100544cc958646b13abe4a84
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/486478833896431808

# %%
with mlflow.start_run():
    mlflow.log_metric("test1",1)
    mlflow.log_metric("Krish1",2)
# Out:
# 🏃 View run debonair-snipe-713 at: http://127.0.0.1:5000/#/experiments/486478833896431808/runs/b6ff21d1212e41b1932f7e1a019abb4c
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/486478833896431808

# %%
with mlflow.start_run():
    mlflow.log_metric("test2",1)
    mlflow.log_metric("Krish2",2)
# Out:
# 🏃 View run ambitious-crow-693 at: http://127.0.0.1:5000/#/experiments/486478833896431808/runs/3118b20019c14c90bf15648e20d9568c
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/486478833896431808
